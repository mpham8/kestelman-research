# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 from wordcloud import WordCloud
#       2 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'wordcloud'

# %%
def get_file(file_path):

  with open(file_path, 'r') as file:
        text = file.read()
        words = text.split()
        return words

file_path = 'sample_text.txt'
word_list = get_file(file_path)
print(word_list)

word_hash = {}
for word in word_list:
    if word not in word_hash:
        word_hash[word] = 1
    else:
        word_hash[word] += 1
# Out:
# ['\ufeff[00:00:00.410]', '-', 'Speaker', '1', 'All', 'right.', 'So', 'welcome,', 'everyone.', 'It', 'is', 'now', '434.', 'Today', 'is', 'Tuesday,', 'April', '26.', 'This', 'is', 'the', 'meeting', 'of', 'the', 'Central', 'Area', 'Planning', 'Commission.', 'Just', 'in', 'general,', 'comments', 'if', 'you', 'can', 'please', 'turn', 'off', 'your', 'cell', 'phones', 'or', 'put', 'them', 'in', 'silent', 'mode.', 'If', 'you', 'plan', 'to', 'speak', 'for', 'before', 'this', 'body,', 'we', 'ask', 'that', 'you', 'fill', 'out', 'a', 'speaker', 'card', 'in', 'the', 'back', 'and', 'bring', 'it', 'up', 'for', 'us.', "You'll", 'generally', 'each', 'have,', 'for', 'public', 'comment', 'periods,', 'a', 'minute', 'each', 'to', 'speak.', "We're", 'going', 'to', 'jump', 'right', 'into', 'it.', 'Agenda', 'item', 'number', 'one', 'is', "director's", 'report.', '[00:00:32.570]', '-', 'Speaker', '2', 'Good', 'afternoon,', 'commissioners.', 'Connie', 'Polini', 'Tipton', 'for', 'the', 'Department', 'of', 'City', 'Planning.', "I'm", 'in', 'for', 'Kevin', 'again', 'this', 'week.', 'And', 'our', 'single', "director's", 'report', 'item', 'is', 'a', 'reminder', 'to', 'the', 'commissioners', 'of', 'the', 'APC', 'training', 'coming', 'up', 'next', 'week,', 'May', '5,', 'and', 'at', '830.', 'So', 'I', 'have', 'a', 'flyer', 'here,', 'and', "I'll", 'just', 'leave', 'it.', "I'm", 'sure', "you've", 'already', 'received', 'it,', 'but', 'just', 'in', 'case,', "we'll", 'have', 'it', 'for', 'you.', 'So', 'we', 'look', 'forward', 'to', 'having', 'that', 'training', 'for', 'you.', '[00:01:00.740]', '-', 'Speaker', '1', 'Thank', 'you', 'very', 'much.', 'Thanks,', 'Jindeta.']

# %%
word_hash
# Out:
# {'\ufeff[00:00:00.410]': 1,
#  '-': 3,
#  'Speaker': 3,
#  '1': 2,
#  'All': 1,
#  'right.': 1,
#  'So': 3,
#  'welcome,': 1,
#  'everyone.': 1,
#  'It': 1,
#  'is': 5,
#  'now': 1,
#  '434.': 1,
#  'Today': 1,
#  'Tuesday,': 1,
#  'April': 1,
#  '26.': 1,
#  'This': 1,
#  'the': 6,
#  'meeting': 1,
#  'of': 3,
#  'Central': 1,
#  'Area': 1,
#  'Planning': 1,
#  'Commission.': 1,
#  'Just': 1,
#  'in': 5,
#  'general,': 1,
#  'comments': 1,
#  'if': 1,
#  'you': 4,
#  'can': 1,
#  'please': 1,
#  'turn': 1,
#  'off': 1,
#  'your': 1,
#  'cell': 1,
#  'phones': 1,
#  'or': 1,
#  'put': 1,
#  'them': 1,
#  'silent': 1,
#  'mode.': 1,
#  'If': 1,
#  'plan': 1,
#  'to': 5,
#  'speak': 1,
#  'for': 7,
#  'before': 1,
#  'this': 2,
#  'body,': 1,
#  'we': 2,
#  'ask': 1,
#  'that': 2,
#  'fill': 1,
#  'out': 1,
#  'a': 4,
#  'speaker': 1,
#  'card': 1,
#  'back': 1,
#  'and': 3,
#  'bring': 1,
#  'it': 2,
#  'up': 2,
#  'us.': 1,
#  "You'll": 1,
#  'generally': 1,
#  'each': 2,
#  'have,': 1,
#  'public': 1,
#  'comment': 1,
#  'periods,': 1,
#  'minute': 1,
#  'speak.': 1,
#  "We're": 1,
#  'going': 1,
#  'jump': 1,
#  'right': 1,
#  'into': 1,
#  'it.': 2,
#  'Agenda': 1,
#  'item': 2,
#  'number': 1,
#  'one': 1,
#  "director's": 2,
#  'report.': 1,
#  '[00:00:32.570]': 1,
#  '2': 1,
#  'Good': 1,
#  'afternoon,': 1,
#  'commissioners.': 1,
#  'Connie': 1,
#  'Polini': 1,
#  'Tipton': 1,
#  'Department': 1,
#  'City': 1,
#  'Planning.': 1,
#  "I'm": 2,
#  'Kevin': 1,
#  'again': 1,
#  'week.': 1,
#  'And': 1,
#  'our': 1,
#  'single': 1,
#  'report': 1,
#  'reminder': 1,
#  'commissioners': 1,
#  'APC': 1,
#  'training': 2,
#  'coming': 1,
#  'next': 1,
#  'week,': 1,
#  'May': 1,
#  '5,': 1,
#  'at': 1,
#  '830.': 1,
#  'I': 1,
#  'have': 2,
#  'flyer': 1,
#  'here,': 1,
#  "I'll": 1,
#  'just': 2,
#  'leave': 1,
#  'sure': 1,
#  "you've": 1,
#  'already': 1,
#  'received': 1,
#  'it,': 1,
#  'but': 1,
#  'case,': 1,
#  "we'll": 1,
#  'you.': 2,
#  'look': 1,
#  'forward': 1,
#  'having': 1,
#  '[00:01:00.740]': 1,
#  'Thank': 1,
#  'very': 1,
#  'much.': 1,
#  'Thanks,': 1,
#  'Jindeta.': 1}
