# %%
from pydantic import BaseModel
from openai import OpenAI
from keys import open_key
import os
from datetime import datetime
import pandas as pd

# %%
dataset_folder = "labeled"
datasets = ["06-13-2013audio_08DIR12-2218_labeled.csv", "09-07-2017 audio_6 APCNV-2016-565_labeled.csv", "09-12-2017audio_6 ZA-2017-210-CU-1A_labeled.csv"]

labeled_df = pd.DataFrame()

for data_file in datasets:
  file_path = dataset_folder + "/" + data_file
  data_file_df = pd.read_csv(file_path)
  labeled_df = pd.concat([labeled_df, data_file_df], ignore_index=True)

labeled_df
# Out:
#      speaker                                               text  label
# 0          2   Thank you James, me, congratulations. Thank y...    NaN
# 1          8                                                you    NaN
# 2          2   That was a bad joke. We should go out to lunc...    NaN
# 3          8                        you  We should go out.  you    NaN
# 4          2   We've been waiting all day to hear from you, ...    NaN
# ..       ...                                                ...    ...
# 305        4                                                you    NaN
# 306        8                                                you    NaN
# 307        4                                         Thank you.    NaN
# 308        8   Commissioner Chun Kim, so we're going to wait...    NaN
# 309        4                                         Thank you.    NaN
#
# [310 rows x 3 columns]

# %%
# Replace NaN values in 'label' column with 2
labeled_df['label'] = labeled_df['label'].fillna(2)
# Drop the speaker column
labeled_df = labeled_df.drop('speaker', axis=1)
# Drop the index column
# labeled_df = labeled_df.reset_index(drop=True)



#do test train split - make sure the test set is 20/20/40
#-1 is oppose, 1 is support, NaN is neither
#want 0 oppose, 1 support, 2 neither

# Convert NaN to 2 (neither), -1 to 0 (oppose), 1 stays as 1 (support)
labeled_df['label'] = labeled_df['label'].map({-1: 0, 1: 1, 2:2})

# # Create test dataset with specific label counts
# test_df = pd.concat([
#     labeled_df[labeled_df['label'] == 0].sample(n=3, random_state=42),
#     labeled_df[labeled_df['label'] == 1].sample(n=3, random_state=42), 
#     labeled_df[labeled_df['label'] == 2].sample(n=10, random_state=42)
# ])

# # Create train dataset from remaining data
# train_df = labeled_df.drop(test_df.index)

# # Convert to Dataset objects
# test_dataset = Dataset.from_pandas(test_df)
# train_dataset = Dataset.from_pandas(train_df)

# # Combine into a DatasetDict
# split_dataset = DatasetDict({
#     'train': train_dataset,
#     'test': test_dataset
# })

# print("\nTest Dataset:")
# print(split_dataset["test"])

# %%
labeled_df
# Out:
#                                                   text  label
# 0     Thank you James, me, congratulations. Thank y...      2
# 1                                                  you      2
# 2     That was a bad joke. We should go out to lunc...      2
# 3                          you  We should go out.  you      2
# 4     We've been waiting all day to hear from you, ...      2
# ..                                                 ...    ...
# 305                                                you      2
# 306                                                you      2
# 307                                         Thank you.      2
# 308   Commissioner Chun Kim, so we're going to wait...      2
# 309                                         Thank you.      2
#
# [310 rows x 2 columns]

# %%
instructions = """
Prompt:
You are an expert assistant specializing in analyzing public comments from housing meetings about project proposals. Your task is to determine whether a given comment expresses support, opposition, or a neutral/unclear stance regarding the proposed project.

Classification Instructions:
	•	Support (Output: 1) → The comment clearly expresses approval, endorsement, or a positive sentiment toward the project.
	•	Example: “This development will bring much-needed housing to our community.”, “I am here on behalf of the project.”
	•	Oppose (Output: 0) → The comment clearly expresses disapproval, criticism, or a negative sentiment toward the project.
	•	Example: “This project will increase traffic and ruin the character of our neighborhood.” 
	•	Neutral/Unclear (Output: 2) → The comment is ambiguous, lacks a clear stance, discusses unrelated topics, or is procedural in nature.
	•	Example: “Have the environmental studies been completed?”

Additional Guidelines:
	•	Explicit vs. Implicit Sentiment: If a comment does not explicitly state support or opposition but implies a stance, classify accordingly.
	•	“This project will improve local businesses” → Likely support (1)
	•	“This project will increase noise pollution” → Likely oppose (0)
	•	Multiple Sentiments: If a comment contains both supportive and opposing elements, classify based on the dominant sentiment. If it is truly balanced, classify as neutral (2).
	•	“I like the new housing, but I’m worried about parking.” → Likely support (1)
	•	“This will add jobs, but it also displaces residents.” → Likely neutral (2)
	•	Unrelated or Procedural Comments: If a comment discusses general meeting logistics, requests for clarification, or unrelated concerns, classify as neutral (2).
	•	“Will there be another public hearing?” → Neutral (2)
	•	“Can we get a traffic impact report?” → Neutral (2)

Output Format:

For each comment, return a single integer:
	•	1 → Support
	•	0 → Oppose
	•	2 → Neutral/Unclear
"""

# %%
truelabels_ls = labeled_df['label'].tolist()
type(truelabels_ls)
# Out:
# list

# %%
text_ls = labeled_df['text'].tolist()
type(truelabels_ls)
# Out:
# list

# %%
client = OpenAI(api_key=open_key)
class Model(BaseModel):
    predicted_label: int

# %%
predlabels_ls = []
for comment in text_ls:
  completion = client.beta.chat.completions.parse(
    model="gpt-4o-mini",
    messages=[
        {"role": "system", "content": instructions},
        {"role": "user", "content": comment},
    ],
    response_format=Model,
)
  print(f'getting prediction for: {comment}')
  pred = completion.choices[0].message.parsed
  
  print(f'predicted label: {pred.predicted_label}')
  # predlabels_ls.append(pred.predicted_label)
  predlabels_ls.append(pred.predicted_label)

predlabels_ls
# Out:
# getting prediction for:  Thank you James, me, congratulations. Thank you for the nice project.  commissioners we have one last case. I think Debbie we're going to go to lunch now and  Thank you.
# predicted label: 2
# getting prediction for:  you
# predicted label: 2
# getting prediction for:  That was a bad joke. We should go out to lunch. Let's go out to lunch.
# predicted label: 2
# getting prediction for:  you  We should go out.  you
# predicted label: 2
# getting prediction for:  We've been waiting all day to hear from you, Debbie.  commissioners can we all hang in there?  up here.
# predicted label: 2
# getting prediction for:  Good afternoon commissioners Debbie Lawrence, Department of City Planning. This is an appeal of a density bonus compliance review case and these are director determinations and these are but the appeals go to city planning commission.
# predicted label: 2
# getting prediction for:  And again, I think the report is pretty clear. So if you can do it as succinctly as you can.
# predicted label: 2
# getting prediction for:  can do.  Thank you.
# predicted label: 2
# getting prediction for:  And do we have an applicant here?  and do we have the appellant?  Are you the appellant?  Okay, so you're both here.  Great.  I don't have speaker cards.  Did you? Thank you.  Are you Aaron? I've got yours.
# predicted label: 2
# getting prediction for:  So staff recommends denying the appeal and the project description.  It's for 39 residential units in the Hollywood community plan area. Point City of Place, this is just south of Sunset Boulevard and east of La Brea. It's a vacant site and it's 39 total units, 36 market rate and three affordable units. They were eligible for two incentives, a 20% decrease in the required front yard, allowing a depth of 12 feet and a 20% increase in the allowable FAR from 3 to 1 to 3.6 to 1, and it includes 78 parking spaces and complies with all other municipal code sections.  So state density bonus law states that when an applicant seeks a density bonus, the city is required to grant it unless the appellant can prove that either the incentives are not necessary for inclusion of the affordable units or that there's a detrimental impact on physical safety and the environment.  owner of the building directly.  to the south of the site and the appeal points had to do with environmental uses and conditions that were mitigated in the mitigated negative declaration. So the appeal points had to do with noise and dust during construction and then a couple of process issues.  This is the site. It just shows that it's a vacant site and it's surrounded by  other multifamily residential uses.  This shows that the residential area, it's R3 zoning, and then it's commercial, just a long-sense at Boulevard to the north of the site.  These are some pictures of the site. This is the actual vacant site with the building to the west of it.  This is the adjacent property on the north side by sunset boulevard. And this is the south, the property of the south, which is the appellance property.  This is across the street from the subject property just a typical multi-family building in the area.  And then we have some drawings that we included earlier today in your packet. And I'm good. I was going to have Nicole Sanchez, the staff planner come up and just walk you through. The findings are made based on design guidelines in the Hollywood community plan. And that's what the director's determination did was was look for facade articulation. But this just shows you I'll just have her walk you through the plans.
# predicted label: 2
# getting prediction for:  after a new commissioners, Nicole Sanchez with the Pioneer Department. So the slide that you see here is the front elevation of the building facing east onto Punxeria Place.  As previously mentioned, this project is a density bonus project, therefore it complies with section 12.22, 825 of the LEMC.  which requires any density bonus project with on menu incentives to comply with certain design features.  This project also incorporates some of the Hollywood Community Plan Design Guidelines, as well as the Planning Department's City of White Residential Design Guidelines.  Some of those guidelines include articulation on the facade that are but a street with a change in material, textures or a break and plane.
# predicted label: 2
# getting prediction for:  So I'm going to interrupt if that's okay. I think this is again pretty clear. And this has already been approved. The project has, you know, and now it's back here just for the appellant. So unless you have some summation remarks, I'd like to go right to the
# predicted label: 2
# getting prediction for:  Thank you.  a few points maybe?
# predicted label: 2
# getting prediction for:  Yes, please. That would be perfect.
# predicted label: 2
# getting prediction for:  Okay.  So here is a summary of the appeal points that we received.  They're primarily related to the short-term construction impacts.  which have all been mitigated either through the M&D or conditioned in the director's determination.  So once again, we recommend denial of the appeal and sustaining the director's donation, approving, identity bonus compliance review. Great.
# predicted label: 2
# getting prediction for:  Thank you very much. Commissioners, if everybody's comfortable, I'd like to go right to the appellate. And here from him first.  if I put five minutes on the clock, would that be enough?  you
# predicted label: 2
# getting prediction for:  went to  you  Let's go to four. Good afternoon commissioners. My name is Aaron Kugliak and I'm the owner of the 1435-37-Pinsides Head Place. The site is directly adjacent to the proposed construction site. We're basically here to object to the whole project since there was no notices that were ever.  sent to us other than 90 days excavation notice we own this property for seven years there are three partners
# predicted label: 0
# getting prediction for:  and you're immediately adjacent, right? I'm sorry? You're property.
# predicted label: 2
# getting prediction for:  directly adjacent about 120 feet of common line.
# predicted label: 2
# getting prediction for:  and no notice is one of the points.
# predicted label: 2
# getting prediction for:  No notices that we are aware of were given to either me or two of my other partners.  And we basically would like an opportunity to go through the same process. I mean, as I said here since 8 o'clock in the morning and observed, you know, other people go through. I mean, we're against it.  Our tenants are against it. We have elderly tenants on the property. We have people that work night shifts on the property.  I mean, it's a huge impact.  But  One of the most important things is blatant refusal of the developer to meet with us and discuss anything. I mean, once we received the only notice that we have received was 90-day excavation notice. And the notice stated that within 90 days the excavation is going to start at zero feet from the property line. Zero feet.  There was no proposed structural engineering report, structural survey of our property. How it's going to be affected? How the shoreings is going to be done? Are they going to use tiebacks, going underground into our property? I mean, we send an email asking the developer for a meeting to meet with us. There was no response.  So other than filing a lawsuit to protect our interests in this property, I just don't know what else to do.  Thank you.
# predicted label: 0
# getting prediction for:  Aaron, thank you for being here.  Can I invite up the applicant and would you address those appeal points for us?
# predicted label: 2
# getting prediction for:  First of all, my name is Don Tolentino and I'm here for Isaac Coansett for San Jose San Jose  I think that Banner's my most is the invention that we  we refuse to be...  to being communication with them.  Actually, you talk to me and don't tell anyone before first.
# predicted label: 2
# getting prediction for:  So what did you, yeah, what did you talk to us? Talk to us and just do your best to describe what you understand.
# predicted label: 2
# getting prediction for:  So what are you?  I'm sorry.  but you understand. So I received that call and immediately gave it to the owners and I believe they responded to them.  and I asked specifically to send an email to the owner.  and  I don't know what happened then from then.
# predicted label: 2
# getting prediction for:  So there's the notice issue and how about the structural soils reports, all of that.
# predicted label: 2
# getting prediction for:  the night shift.  about the noteworthy. Which not, sir?  He said that he's not been notified. When we fight the case, we have our religious, the abatting owners, mailing notices and everything. So I believe he was notified. Maybe he didn't get it from the mail. So I think we cannot be blamed for that, sir.
# predicted label: 2
# getting prediction for:  Here is, let's, you know, I can't speak out of turn. In plus, it's not recorded unless you're talking into a microphone, so thank you. Anything else you want to add? I'm going to invite staff back up. I'm just here to have the questions. Okay, thank you. Thanks for being here, both of you. Can I invite staff back up?
# predicted label: 2
# getting prediction for:  I can't speak out of it.  Thanks for coming.  Okay.
# predicted label: 2
# getting prediction for:  Can you put your appeal points back on the screen?  So the access, can you guys speak to that at all?  And also if you would speak, this is a very different process than the previous project we saw in terms of both public engagement and participation. Maybe you could explain that to us why this process is different.
# predicted label: 2
# getting prediction for:  So it was a director's determination, so there was no public hearing, but the determination went out to both the appellant and the property.  or the property owner and the applicant.  And then when it was appealed by the adjacent property owner, we also sent another.  another determination and both of them received that as well. Now the addresses that we use are what we have on our record.  And possibly there was an issue with that, but I mean, I can state the two addresses if you would like me to. But if you want me just to cover the appeal points. So the appeal points in the letter.
# predicted label: 2
# getting prediction for:  I'm going to address one at a time if we could. So as far as the notice, so after the director's made a determination, then notice was sent by mail. Yes. And did that notice give them some information as to how they could respond if they had concerns? Was there a telephone number provided in address? Yes. OK.
# predicted label: 2
# getting prediction for:  data.
# predicted label: 2
# getting prediction for:  Okay.  Yes.  Yes.  you  Yeah, it's provided. It was a determination letter. So it went in and it states on that it's a 15 day appeal period on the original determination.
# predicted label: 2
# getting prediction for:  And do you have a record of what addresses that notice was sensitive? Yes. And is that the same address that the appellant used for his appeal? I don't see the appeal here. I'm trying to find the actual appeal table work. But is that the same address, do we know?
# predicted label: 2
# getting prediction for:  Yes.
# predicted label: 2
# getting prediction for:  you
# predicted label: 2
# getting prediction for:  very  Yes, it is. It's 11601 Santa Monica Boulevard.  And that's the label that it went to.
# predicted label: 2
# getting prediction for:  Okay.
# predicted label: 2
# getting prediction for:  you  you  And then the other one is 1-1-3-1-5, Dona Lola Drive, which is the appellance address that it was sent to, which is not the address of the actual property.
# predicted label: 2
# getting prediction for:  Thank you.  And it's the same address that the excavation notice I assume was sent to.  that the balance was the first key to learn to bit.
# predicted label: 2
# getting prediction for:  Yeah.  Right, the Studio City address, it's the Dona Lola drive address that we send it to, that we send our determination to.
# predicted label: 2
# getting prediction for:  Okay.
# predicted label: 2
# getting prediction for:  And I think it's the same, I mean we have the same system so building and safety would use the same address. It's the assessor and the city clerk address that we have in our system.
# predicted label: 2
# getting prediction for:  Do you have a copy of the notice? Any chance that we take a look at?
# predicted label: 2
# getting prediction for:  Yes.  We included in your packet.  We've also got the original one.  but here's the actual notice.
# predicted label: 2
# getting prediction for:  I'd love a chance to look at that. And the other point that I want to focus on, at least for me, the purposes is, while I can understand a neighbor having concerns when a large construction project is going to be next to them, it seems to me in reading the report that they had a matter of right they could build 29 units. So we're only dealing with the density bonus, the difference between the construction of 29 and 39. I think we need to be mindful of that when we look at
# predicted label: 2
# getting prediction for:  So the appeal points, we responded since the appeal points had to do with impacts related to construction, such as noise and dust. And there were some points there that had to do with the process that we were just talking about. We, since an emitting a neck deck was prepared for it, the mitigation measures addressed all of the appeal points. And that was how we responded and recommended, it made our recommendation to deny the appeal.
# predicted label: 2
# getting prediction for:  And that's an explanation you could offer to the appellant so that he does understand that there are conditions that you do address.
# predicted label: 2
# getting prediction for:  right.  and the conditions were listed in the determination letter. All of the, like with other determinations, we have administrative conditions, but all of the conditions for the environmental were listed in that determination letter.
# predicted label: 2
# getting prediction for:  on it.  the structural integrity of the property. Could you explain to us how that's handled?
# predicted label: 2
# getting prediction for:  What's that was? How that's handled.  There was an appeal point in the letter that just said, soils and engineering report, or it just referenced the report, a structural engineering report.
# predicted label: 2
# getting prediction for:  So as soils engineering report would be they were worried about the structure.
# predicted label: 2
# getting prediction for:  They were worried about the structural, and there was a report. Right.
# predicted label: 2
# getting prediction for:  ensuring design will be
# predicted label: 2
# getting prediction for:  We required to.
# predicted label: 2
# getting prediction for:  required for this project.
# predicted label: 2
# getting prediction for:  this question. Mr. Murnister, a record in conditions 11 and 12, feel specifically with that. And again, in the
# predicted label: 2
# getting prediction for:  mission.  Thank you.  you
# predicted label: 2
# getting prediction for:  I'm a doctor.
# predicted label: 2
# getting prediction for:  you
# predicted label: 2
# getting prediction for:  you
# predicted label: 2
# getting prediction for:  you  Yeah, the conditions. And they were repeated in the appeal letter as well.  So air pollution, demolition, grading, and construction activities were addressed, you know, such as  transported off site and wetting the dust, the standard mitigation measures for construction dirt.  There was also...  The ones having to do with noise and there was a minimum five foot and two foot landscape buffer to be put in against all walls.
# predicted label: 2
# getting prediction for:  And I guess I would add this is not unusual, this process, and that I can see in any way. So maybe staff would take the time to walk the appellant through and explain to them that this is a very common situation and the city's, I think, very competent and dealing with these points. I'm ready for a motion unless we need further discussion.
# predicted label: 2
# getting prediction for:  explained.
# predicted label: 2
# getting prediction for:  Dana?
# predicted label: 2
# getting prediction for:  I still so do you have the actual notice that was originally sent out though that's what I was hoping to see
# predicted label: 2
# getting prediction for:  It was a director's determination so there was no notice of a public hearing because it was not a public hearing. But we did send out was a determination letter which showed the director's determination.
# predicted label: 2
# getting prediction for:  But that went to the neighbor.
# predicted label: 2
# getting prediction for:  Exhibit me in your package and I believe it's the one that I
# predicted label: 2
# getting prediction for:  I don't see that address to the neighbor.
# predicted label: 2
# getting prediction for:  change Williamson.  Good.
# predicted label: 1
# getting prediction for:  Sean Abon since the planning department we don't address the neighbor in the letter. Our records show in the file who we mailed it to and we received no letters or envelopes that were returned saying that it was not sent. Okay, that's I just want to ask for this.
# predicted label: 2
# getting prediction for:  Okay.
# predicted label: 2
# getting prediction for:  Okay, I just want to say that.
# predicted label: 2
# getting prediction for:  So the property owner is the neighbor. That's the one that says point, Sedia. The one, Wiseman development.
# predicted label: 2
# getting prediction for:  Thank you.  Well, that's the same address as the applicant and the representative. All I need to know is this document exhibit being our package is the document that was sent correct.
# predicted label: 2
# getting prediction for:  Right, that's the original and of course the appellant wouldn't be on on that one, but on the appeal notice the appellant is is listed there along with the with the property owner. So there were two the first one would not include.
# predicted label: 2
# getting prediction for:  right.
# predicted label: 2
# getting prediction for:  Um  The appellant accept that determinations are sent to abutting property owners.  So the appellant did include, did get that notice. It's just not showing on your determination, but they're included as an inviting property owner.
# predicted label: 2
# getting prediction for:  Final comments from Dana more something else final comments Regina did you want to say?
# predicted label: 2
# getting prediction for:  on the screen.
# predicted label: 2
# getting prediction for:  I just think that something that this illuminates is that we have seen this regularly and obviously the department sees this regularly But a joining property owner is probably going to see this once in their property owning lifetime And so for us to just be as sensitive as possible to explaining the process for them What is you know legally required how those legal requirements are met that we you know offer some patients on our part and obviously on the staff which I'm sure you do to help neighboring property owners understand what their rights are when their rights can be evoked at what point in the process and that we do that with some  So we don't, I mean, we throw around acronyms. We do a lot of things because we get used to doing it. And I just think that it's important for us to be sensitive to that. For our problem. So to take the time to do that with the joining property owner, I think, would be appreciated for everybody. Thank you.
# predicted label: 2
# getting prediction for:  you
# predicted label: 2
# getting prediction for:  I promise.  because the first time they would hear of it would be when they would receive the determination. And so for many people that can be quite...
# predicted label: 2
# getting prediction for:  Exactly. And for a density bonus case, there are ways that it takes it to a different level in terms of notice and what becomes a director's determination.
# predicted label: 2
# getting prediction for:  you  for a density of
# predicted label: 2
# getting prediction for:  and I would appreciate that as well to give, you know, the appellant as much confidence in the process as we can.  Sean.
# predicted label: 2
# getting prediction for:  With that in mind, I'm prepared to make a motion that we denide the appeal and sustain the director's determination.
# predicted label: 0
# getting prediction for:  Do I have a second?  you
# predicted label: 2
# getting prediction for:  second.
# predicted label: 2
# getting prediction for:  Thank you, Camille. James, would you pull the commission?
# predicted label: 2
# getting prediction for:  Certainly, Commissioner Burton. Aye. Commissioner Aing.  you
# predicted label: 2
# getting prediction for:  Yes.
# predicted label: 2
# getting prediction for:  you  Commissioner Cardoso. Yes. Commissioner Freer. Yes. Commissioner Hove Gullian. Yes. Commissioner Lassen.
# predicted label: 2
# getting prediction for:  Yeah.  Yes.
# predicted label: 2
# getting prediction for:  you
# predicted label: 2
# getting prediction for:  you
# predicted label: 2
# getting prediction for:  you
# predicted label: 2
# getting prediction for:  Yes.  Mr. Curlman.  Yes, Commissioner Romero? Yes. Commissioner Rochon? Yes. Motion carries.
# predicted label: 2
# getting prediction for:  Yes.  Thank you all very much.
# predicted label: 2
# getting prediction for:  Commission President Russian before you again in the meeting. If I may pull the commission just very quickly before we all depart. I'm looking for your availability to participate in an all day hearing on Friday June 28th. And I know Commission President, you will be unavailable on that day. Are there others that would also be unavailable?
# predicted label: 2
# getting prediction for:  Lisa.
# predicted label: 2
# getting prediction for:  I'm traveling that day. It's Commissioner Burton.
# predicted label: 2
# getting prediction for:  Yeah, Commissioner Perlman, I'll be out of town.
# predicted label: 2
# getting prediction for:  I will be here.  I'm also unavailable on the 28th.
# predicted label: 2
# getting prediction for:  Commissioner Eng, I will be here.  I'm sorry, I will be here, you will be.  What's the gear?  We're exploring a possible all day long hearing on the Wyvernwood project.  Friday the 28th.  you
# predicted label: 2
# getting prediction for:  I will.
# predicted label: 2
# getting prediction for:  want to be a
# predicted label: 2
# getting prediction for:  We're gonna go home.
# predicted label: 2
# getting prediction for:  you
# predicted label: 2
# getting prediction for:  you
# predicted label: 2
# getting prediction for:  With that, we are adjourned.
# predicted label: 2
# getting prediction for:  that.
# predicted label: 2
# getting prediction for:  you
# predicted label: 2
# getting prediction for:  Next item on the agenda is some  It's the case we're here to hear. It's case APCNV, 2016-565-ZC-BL. The address of the property is 8730 North Edawanda Avenue. I believe that's in Northridge. It's the Constituc District 12. Can we have a departmental report, please?
# predicted label: 2
# getting prediction for:  Hello, everyone. My name is Lucerito Martinez. I'm the project planner assigned to the case. The project consists of the demolition of an existing single family home and the subsequent construction of a three-story eight-unit apartment building with a semi-subterranean garage. It will provide a total of 15 parking spaces. The requested entitlements include a zone change from R1-1 to R3-1 to construct the 8-unit apartment building and also include say 15-foot building line removal created by ordinance 1-29661. The recommendation is to approve the categorical exemption class 32, the zone change from R1-1 to TQR3-1.  and the building line removal. And I'm here to answer any questions.
# predicted label: 2
# getting prediction for:  That's the report. Do we have any questions from the Commission for the Department on the report?
# predicted label: 2
# getting prediction for:  No questions.
# predicted label: 2
# getting prediction for:  Okay.  Hearing none and there's no other speakers on this on the item of the chair will entertain a motion from a commissioner on this item. Commissioner.  As general comments.
# predicted label: 2
# getting prediction for:  you
# predicted label: 2
# getting prediction for:  Thank you.  channel comments.
# predicted label: 2
# getting prediction for:  you  Sorry.  I'm sorry, I'm sorry, I'm sorry, I'm sorry, I'm sorry, I'm sorry, I'm sorry, I'm sorry, I'm sorry, I'm sorry, I'm sorry, I'm sorry, I'm sorry, I'm sorry, I'm sorry, I'm sorry, I'm sorry, I'm sorry, I'm sorry, I'm sorry, I'm sorry, I'm sorry, I'm sorry, I'm sorry, I'm sorry, I'm sorry, I'm sorry, I'm sorry, I'm sorry, I'm sorry, I'm sorry, I
# predicted label: 2
# getting prediction for:  you
# predicted label: 2
# getting prediction for:  I'm sending this one.
# predicted label: 2
# getting prediction for:  you
# predicted label: 2
# getting prediction for:  It's a general comment request.  we've already had public it it i'm sorry i just saw something on here that he wrote  Um  Bye.  What is your, what is your, what is your
# predicted label: 2
# getting prediction for:  If there's a comment card...  When did you father what comment card for this agenda item?
# predicted label: 2
# getting prediction for:  i don't have i don't have any cards for against the side  This is a general comment. We've already had public comment.  and
# predicted label: 2
# getting prediction for:  comment on item six.
# predicted label: 2
# getting prediction for:  Yeah.
# predicted label: 2
# getting prediction for:  Are we?
# predicted label: 2
# getting prediction for:  Yeah, this is where NACA before.  Yeah, this is when I see a before you can make a motion you have to  Here the general comments or comments from the applicant or the appellant having
# predicted label: 2
# getting prediction for:  I'm just happy.  He's in lock and purport the most. Guy another minute.
# predicted label: 2
# getting prediction for:  Good.
# predicted label: 2
# getting prediction for:  By the way  you
# predicted label: 2
# getting prediction for:  yes i'd like to know what is the name of the puppet well bully bull bully bull but the ball everybody goes by must
# predicted label: 2
# getting prediction for:  But I'm going to be back.  down by
# predicted label: 2
# getting prediction for:  by their name.
# predicted label: 2
# getting prediction for:  Thank you.
# predicted label: 2
# getting prediction for:  Mr. Puppet. Well, no, but he's known as Mr. Puppet. Okay. Please go ahead. You got one minute.
# predicted label: 2
# getting prediction for:  you
# predicted label: 2
# getting prediction for:  So on my comment card, they put down general comments about item six. So on the corner on the top left, is that right?
# predicted label: 2
# getting prediction for:  Web.
# predicted label: 2
# getting prediction for:  There's an item number that's listed.  You look at that for the item and that will tell you the item number.  So again!  We have a rookie here. Rookie. And that's how we do it.  The Brown Act will be satisfied. One minute, that's her blessing.  two minutes is justice. So if you do one minute, you want to be a herb wasn't.  Any of you want to be a herbison?  Any of you want to have two mortgages that you can't pay raise your hands. And his lovely wife just took a job with the AQMD and spoke against public comment while she's working as the outreach coordinator, bitch. He is.
# predicted label: 2
# getting prediction for:  Thank you.  Hold on a minute, we may have another comment card coming in.  Is that for Speaker Card?
# predicted label: 2
# getting prediction for:  Bravo, Vegas, Senior Adam. And yes, it is another speaker card for item six. The address on the speaker card was actually incorrect. It should be Edawanda and I believe it reads. Nordoff, I asked the individual to fill out the speaker card so he can submit it, which I would then hand over to the Commission President so that the individual can have a minute to speak on the item.
# predicted label: 2
# getting prediction for:  Okay. So is he going to speak? Do you have a comment card or not? Yes, he will speak. He's currently filling it out. All right. We'll give him a minute or two to do that.
# predicted label: 2
# getting prediction for:  Is that item number six which you'll look at?
# predicted label: 2
# getting prediction for:  We're in number six right now.
# predicted label: 2
# getting prediction for:  All right.  I don't need to speak. I'm supporting the application. I represent the applicant. So please, no issues. I don't need to speak.
# predicted label: 1
# getting prediction for:  Fine.  uh... there there's no opposition against uh... at this point  Okay.  So at this point,  Do you have any, you have a comment you want to make?
# predicted label: 2
# getting prediction for:  Not.
# predicted label: 2
# getting prediction for:  No, no, I don't. Okay. At this point, the chair will entertain a motion from a commissioner.
# predicted label: 2
# getting prediction for:  No, I don't.
# predicted label: 2
# getting prediction for:  On this item I'm going to make a motion please. That's for case number APC envy 2016 565 ZCBL and sequel number ENV 2016 564 CE this is Commissioner Hartwinian so  I motion that determined that based on the whole of the administrative record, the project is exempt from SQL, pursuant to SQL guidelines section 15332, state SQL guidelines class 3021, there is no substantial evidence demonstrating that an exception to a categorical exemption pursuant to SQL guidelines section 153002 applies. This is the, this is the, this is the, this is the, this is the, this is the, this is the, this is the, this is the, this is the this is the, this is the, this is the this is the, this is the, this is the this is the, this is the, this is the this is the, this is the, this is the this is the, this is the, this is the this is the, this approval. I recommend that the City Council adopt a building line removal to remove a 15-foot building line on the east side of Etouwanda Avenue established on the ordinance number 129661.  I adopt that. I asked findings. Advise the applicant that pursuant to California, the state public resources code section to 108 1.6. The city shall monitor or require evidence that mitigation conditions are implemented and maintained throughout the life of the project and city may require any necessary fees to cover the cost of such monitoring and advise the applicant that pursuant to the state efficient wildlife code section 711-0.4 efficient wildlife and or certificate of game exemption is now required to be submitted to the county color prior to or concurrent with the environmental notice of determination filing.
# predicted label: 2
# getting prediction for:  Okay.
# predicted label: 2
# getting prediction for:  Okay, we have a motion.
# predicted label: 2
# getting prediction for:  on the floor, can we get a second?
# predicted label: 2
# getting prediction for:  And second, the motion, this is Commissioner Garcia.
# predicted label: 2
# getting prediction for:  Okay, we have a motion on the floor, a second call for the role.
# predicted label: 2
# getting prediction for:  Just Renee C and you have a motion to approve the staff  recommendations. Commissioner Haratunian, how do you vote?
# predicted label: 2
# getting prediction for:  you  Bye.
# predicted label: 2
# getting prediction for:  Commissioner Garcia, how do you vote? Aye. And Commissioner.  Ray is how do you vote? Aye. And Commissioner Simpson, how do you vote? Aye. And the motion passed.
# predicted label: 2
# getting prediction for:  I'm sorry.
# predicted label: 2
# getting prediction for:  you  I'm going to be pretty good with it.
# predicted label: 2
# getting prediction for:  This is where an ACA we're being recorded and nothing is made. I want to speak. Come up with a microphone on your phone.
# predicted label: 2
# getting prediction for:  I want to speak, come up with a microphone on your M. Please identify yourself.
# predicted label: 2
# getting prediction for:  Robert Lamishaw, JPL zoning on behalf of the applicant. I just wonder if you had a projected date for the plum hearing on this.  I did.
# predicted label: 2
# getting prediction for:  Thank you.
# predicted label: 2
# getting prediction for:  you
# predicted label: 2
# getting prediction for:  I don't believe the board does. Okay. Check with the planning department.
# predicted label: 2
# getting prediction for:  This Christine Sapnara from Planning Department usually once a project is recommended for approval. It's up to the agenda of CD-14 to place it on the plum agenda. So they do their own well thing, they'll let you know though.
# predicted label: 2
# getting prediction for:  Okay.  Thank you.
# predicted label: 2
# getting prediction for:  Okay, we have nothing else on the agenda. I'm going to take an emotion for adjournment.  Thank you.
# predicted label: 2
# getting prediction for:  Second.
# predicted label: 2
# getting prediction for:  Okay, and we are adjourned and we're out. Please. Give me a time. A time.
# predicted label: 2
# getting prediction for:  We're out.  the way the main
# predicted label: 2
# getting prediction for:  He can come to the end.
# predicted label: 2
# getting prediction for: 452
# predicted label: 2
# getting prediction for:  Item number 6. Item number 6 is case number Z82017210CU1A. Project site is 5815-5825 west sunset boulevard. The project is in Council District 13. Appeal of the zoning administrators' determination to approve a conditional use permit to allow a transient occupancy residential structure in an appeal of the categorical exemption. At this time, we will hear from staff and also would like to state that this is a continuance from the state of the state.  are August 8th, 2017.  hearing where we had our public testimony at that time.
# predicted label: 2
# getting prediction for:  Good evening, Commission President and Commissioner. This is Jack John, this is on Administrator who I oversee this case.  items submitted to you or are conditions submitted by the applicant and revised condition number 11, 12, 13 and 15. It should be part of the packet. So the applicant, the property owner has a men 3 conditions in regards to its business model.  and also a young sign manager. I have revised Conditioning 11, 12.  13 and 15 just for more clarity.  Okay.
# predicted label: 2
# getting prediction for:  I'm sorry. Just for the record, I believe Commissioner Delgado needed to make a statement because he wasn't here on the September of August 8 meeting.
# predicted label: 2
# getting prediction for:  Commissioner Dogado, I've reviewed the audio files and the minutes for the last meeting of August 8th and I'm caught up to speed.
# predicted label: 2
# getting prediction for:  Okay, thank you, Commissioner.  So these are the items I request by the commission last time to amend, okay additional item that I submitted to you is  Similar type of cases that will approve because that was a question asked by the commissioner and also I believe that Helen also have a similar that same same question so I Ask our ZAs in the department if they have done any Trans-Analcuban Z-Rest-Entre-Structure projects in the past few years Only Maya Zazefsky replying and she has done one that she approved back in 2013. The project was it's a locating of Venice planning area and it's a conversion.  from the residential apartment into the tours, the transient occupancy, residential structure. It's not exactly the same as the project before you because the project before you maintains both apartment and the tours use, but this one is a complete  conversion. Okay.  I also mentioned that there is a project located on Wojšer, right, right around the MacArthur Park area. I call the applicant and that project never penciled out so it did not become an application. However, what I want to present to you is a joint memo issued by a joint department memo issued by the Planning Department and also  Building safety on February 27th, 2014. Now, this memo basically stays that general plan visioned this route and new  Regional center and district will be the most densely developed.  in Los Angeles and characterised by lively mixed residential commercial and detainment retail and visitors serving uses to help realise this vision. The exception, okay, this memo is to relax the citywide regulation government permitted uses of land and yard requirement for the buildings. Now this memo is stipulated at a hotel, a apartment hotel in CRC1C.5C2C4 and C5 zones. Basically covers all the commercial area. In the central city community plan area or area designated by the community plan as regional center or regional commercial. Okay.  to be exempted with conditional use. Okay, so even a hotel, a part of a hotel is located within 500 feet of an arson. So if you have a project that's located,  Ian  This is a red hatch area. That's a regional center commercial. So this covers the entire downtown. And areas are a long washer boulevard from downtown all the way to Korea town, Western Avenue.  and also  majority area of Hollywood, okay, community, the hatch area.  Project like this, okay, but conforming.  to the criteria if it's a new construction or adapt to reuse, okay, or conversion existing buildings to allow  Um  that has a historical significance, you don't need the conditional use. So my point is that there could be a lot of this project that all they need is just go to building and safety, who a building permit without coming to planning department for a conditional use. Okay. So this project that before you, I don't think qualifies for this.  this memo, but I want to illustrate the fact that there must be a lot of a tourist project.  in the cities of system, that's not before us. And in order to find out, that has to be a search through building premise system.  Okay.  So.  that's all I want to say in regards to the possible distype of cases that occurs in the city. Now for the Mitchell-Politan law,  My feeling is that this is a unique area. It's a unique use. In other area, I will not consider a proof of it, but this project basically serves a creative office use. That's why it's very different. Okay, and I think it's important to maintain the apartment use on site as well. Because this is not a typical hotel use. Now you're got to hear, I think you probably see a couple letters from the Hollywood Chambers and the other one from the NABU Council.  Thank you and for your late neighborhood council.  Thank you.  They talk about the hotel use.  To me, I think this is a very different from the hotel use because this allows, this course, especially for this project, allows longer stay. This is not geared towards a visitor for a c ...
# predicted label: 1
# getting prediction for:  Commissioner Chunkham, so I need one clarification regarding  I guess other cases similar to this. So just to be clear, there are no precedents in place for mixed use in the sense of transient and long term.  Correct.
# predicted label: 2
# getting prediction for:  I have.
# predicted label: 2
# getting prediction for:  Thank you.
# predicted label: 2
# getting prediction for:  That's right. I did not find other ones.
# predicted label: 2
# getting prediction for:  I didn't know.
# predicted label: 2
# getting prediction for:  now.
# predicted label: 2
# getting prediction for:  Okay.
# predicted label: 2
# getting prediction for:  And that.  Sorry, this is strange, but that's only the ones that require conditional use. I think what  Jack.  I was pointing out was that...  If you're in the regional center area, you can go to building and safety and add tours.
# predicted label: 2
# getting prediction for:  Thank you.
# predicted label: 2
# getting prediction for:  to your building, your certificate of occupancy, so you could have both.
# predicted label: 2
# getting prediction for:  you.
# predicted label: 2
# getting prediction for:  tours and just regular dwelling units. It's just that we would have to go through a search of building permits.
# predicted label: 2
# getting prediction for:  mm-hmm.
# predicted label: 2
# getting prediction for:  and to be able to identify how many of those exist throughout the city.
# predicted label: 2
# getting prediction for:  Mr. Chunkan, because...  I'm going to have to ask you to walk through the modified or your  your proposed modifications to the conditions. However, prior to that, I know that two of the commissioners that were at the last hearing regarding this case, who aren't here, I know that some of the biggest concerns during that meeting was pertaining to how to obtain that number of dedication for permanent  or more long-term use versus the transient occupants. And we were having trouble coming up with that type of number.
# predicted label: 2
# getting prediction for:  you  Thank you.  you  I have to refer to the applicant because I think right now they are still maintaining the 52 units as both apartment units and transient occupancy risk and structure units. We can call the applicant up and have them have him to explain that.
# predicted label: 2
# getting prediction for:  Okay, prior to that, can you walk us through this a little bit? I'm not sure if you guys have further questions.
# predicted label: 2
# getting prediction for:  Thank you.  you
# predicted label: 2
# getting prediction for:  Okay.  I do commission to the Ghatau.  I think in addition to how to divvy up the percentage of those units and how to, and their designation, it was also how to distribute them throughout the floors. And I think there was a question versus whether top floor metaphor, metaphor. I do have some questions or some updates that I'd like to get. And I don't know who would have that information. And I read an information regarding, and it came up several times regarding two, four specific, very low income units and whether or not those are regarding four specific very low income units and whether or not those are in fact designated as low income units.
# predicted label: 2
# getting prediction for:  Correct.  We're not full.  some of the things that I'm going to do.
# predicted label: 2
# getting prediction for:  Okay, those four...  This project, Metropolitan Law, it's part of the larger project to the west of the metropolitan creative campus. That created campus, it encompassed the metropolitan tower and the metropolitan creative office. To the west, there's a metropolitan west apartment, I think it's 76 apartment units. That four units that you were talking about, four of our units, that's in that apartment. It's not within the metropolitan law building. Okay.
# predicted label: 2
# getting prediction for:  Great. Sorry, the next question. Yes. Is there an update on the one tenant that was at this unit that was nearing the lease? Nearing the 12 month lease?
# predicted label: 2
# getting prediction for:  Yes.  I think that the tendency will end in September, but we can ask the applicant to clarify. Okay. Now, going back to Commissioner President Chunking's question, I think now
# predicted label: 2
# getting prediction for:  you
# predicted label: 2
# getting prediction for:  Great.
# predicted label: 2
# getting prediction for:  you
# predicted label: 2
# getting prediction for:  The property owner has a submit.  the first three condition, I think the first condition, illustrate their plans for the business model. So they are going to move the existing tenant to the upper floor. So have the lower floor open up for the short-term rentals. So that's the existing plans. But as far as how many units were permanently assigned to apartments and how many units were permanently assigned to the tours, I don't think that we have that information available. So I still maintain that the applicant, it's the property owner still want to do all 52 units as an apartment, both apartments and tours use. How are they going to rent those, the units rent out as the short term I think it's still based on the market demand.  Okay.
# predicted label: 2
# getting prediction for:  Commissioner Trump came and so forward the  conditions 11.  12, 13, 15. Can you just walk us through? I know there were questions regarding the language specifically and so if you can walk us through those changes.
# predicted label: 2
# getting prediction for:  Okay. No. Condition 11. I believe Commissioner Chimorinsky was saying that there has to be some sort of  So, I just added that the applicant  shall not display or be evictive without just cause. So that if the tenant breach the lease agreement as to become nuisance or become the, becomes, or endangered properties or not pay rent, then they can be evicted. But that's why I just add the phrase without just cause as to breach lease agreement. So the lease agreement itself will have terms. So I'm just keeping the language sort of a flexible. Now condition number two, there was a question in regards to the 30 days and 60 days. Now which type of tenants should be served with 30 days or which type of tenants should be served with 60 days. Then I checked the California Department's consumer affairs. It has regulation in regards to the noticing. Now if you  It doesn't, the notice was served to tenet. It, that doesn't matter what type of lease agreement you have. Whether it's months to months or it's a yearly lease, it does not matter. But what matter is how long have you stay on the property? So if you stay on the property for less than one year, then 30 days notice applies. If you, if you have to live on the property for more than a year, 12 months, then 60 days leads will apply. I mean, 60 days notice will apply. So I basically, I change the language. I'd be more clear that the applicant shall comply to the California Department of Consumer Affair and Noticing Requirement, okay?  allow the tenants to stay up additional 30 days, okay, beyond the terms of tenancy, okay, in case they are  relocating. Alright, so this is just an additional month or additional month that they can have.  All right.
# predicted label: 2
# getting prediction for:  I have a question. So to clarify, if they have an existing lease, this says that they can't be terminated without just cause. But once that lease is over, then they can terminate the lease. But these are the.
# predicted label: 2
# getting prediction for:  Bye.
# predicted label: 2
# getting prediction for:  the amount of time that they would be required to give.
# predicted label: 2
# getting prediction for:  Correct, that's right.
# predicted label: 2
# getting prediction for:  Notice. OK.
# predicted label: 2
# getting prediction for:  All right. So condition 13, it has to do with the security. The regional grant already had a security condition, all right. But I think one question was asked whether they will be security patrol. So the property owner agreed that they can off, they can provide security, guard service. Okay, so on site, 24 hours a day. All right, so I add that. The last condition is number 15, that on site manager, I just say that available for 24 hours a day. Now that is already a part of the determination.  Now this is...  The on-site manager is required by the state law for any apartment that's more than 16 units. You have to have a 24 hour on-site manager. This is basically a regulatory compliance measure. I mean, I don't think that it's necessary, but I think having that language basically will, you know, will be more clear to you the property owner.
# predicted label: 2
# getting prediction for:  Thank you.  You can just give me a moment to read through some of the other language.  Commissioner Tom Kim. So I think in terms of just addressing some of the concerns and questions from the last meeting, these proposed modifications to the conditions suffice. How do you guys feel?
# predicted label: 2
# getting prediction for:  Commissioner Doga, I would agree based on the concerns that I have that were addressed earlier and the revised conditions I would be inclined to make a decision.
# predicted label: 2
# ...
# predicted label: 2
# getting prediction for:  because they're not so less considered attorney's office.  Like you mentioned, this commission hears appeals and generally hears appeals and that is the functions commission this commission doesn't obviously act to legal out and enforce the conditions that this commission may or may not impose.  You know, that's divided up between different, you know, separate bodies of the city, you know, DBS being one of them that receives complaints alleging zoning code violation then goes out and investigates them.  you know, in your...  So, for a successful example, it would be sort of for these rules of conduct that you could have a requirement that the applicants submit these rules. So, did you know that they've actually been drafted? That's something that I think can be...  enforced and proof of compliance with that can be reasonably shown.
# predicted label: 2
# getting prediction for:  Haha.
# predicted label: 2
# getting prediction for:  Like to my point with this simply to highlight that  the commission just consider whether or not these particular conditions are currently drafted with another language in there that  should be removed because.  They don't lend themselves to...  If the Netherlands was either efficient enforcement or it puts the city in a position where it's arbitrating dispute between  you know, the person who's renting and the person who's, you know, the less in the less or and that's what's the point I wanted to make.  The point of enforcement is obviously a much larger.  issue that  you know, I sit here in this truck and, you know, give you the...  Mr. Chan-Chi-Len.
# predicted label: 2
# getting prediction for:  Mr. Chang-Chan, well then to get a little bit more specific to this particular, I think you're looking at the second bullet point. So I guess where I am confused is what's the difference between outlining.  the quiet hours, right, commencing at 10 PM on week days and 11 PM on weekend, versus a three-staric rule for complaints. I guess I'm just not seeing, because to me they're equally specific.
# predicted label: 2
# getting prediction for:  the nurse for the last G.C.D. Chinese Office.  I think the issue that I wanted to highlight is having a rules of conduct that outline when quiet hours being your 10 p.m. on weekdays and 11 p.m. on weekends.  It's something that is very precise. You can have the applicant submit these rules of conduct, and it states clearly that quite hours are from 10 p.m.  on the weekdays and 11 p.m. on the weekends, when it comes to sort of three strikes in your out sort of a role.  my concern with was that the commissioners currently drafted  doesn't explain what a strike is for.  you know we heard from the outlook today that it was over 30 day period so once again the condition has crumly drafted didn't have that so that was my concern that seemed that it was a bit vague as far as what a strike um...  would be categorized as a strike and  That...  it would then put the city in a position where it would be  under these conditions seems that it would be enforcing  The...  You know the repercussions for these violations framing three strikes, whereas that seemed to be more of an issue between  Like said, the less one, the less E2.  decide what sort of repercussions should result from violations of the rules of conduct. Establishing rules of conduct, I think something that is within the purview of this commission and something that can be presented.  to planning step-to-show. These are the rules of conduct. These are quiet hours. These are, you know, whatever other rules. You know, these are the rules that people are expected to abide by while staying at this particular site.  but issues of removing short-term tenants or three strikes in your route.  seem to be more an issue between.  the applicant as the one who's.  putting the units up for rent and then those people who then decide to rent those units.  So that was the distinction I was making between just having quite hours to start at 10pm on the weekdays and 11pm on the weekends. That's something that can be clearly put out, you know, in a short paragraph from bullet point on, a rules of conduct, but this issue of three strikes and what is a strike? Just seem to be a little...  to unclear as currently drafted. And I just wanted to highlight that to the commission as a  as a point that maybe unclear at the moment.  Commissioner.
# predicted label: 2
# getting prediction for:  Commissioner Mendes, I think the one possible solution to this would be.  to eliminate  specifics like that and require that rules of conduct be created, but also that there be some sort of complaint process for existing tenants so that  as issues come up as part of this transition that  existing tenants have a right to or have an ability to communicate that and have those needs addressed.
# predicted label: 2
# getting prediction for:  All right, staff, zoning minister is out. So the housing department currently enforce the housing conditions and regulations. So if there's any nuisance or current side, the tenant can always contact the city to enforce any sort of a nuisance, okay? So but I do agree with the city attorney in regards to the three strike rule, okay? I propose I went delete that attorney in regards to the three strike rule. I propose I won't delete that because in case there is a dispute between the tenants and property owner, then City will be dragged in. And that will not be involved in between the private contract. Now this is different than the City regulation, the LEMC, whereas the fence case, the regulation comes from the LEMC, so the city has to enforce that. But this thing is basically agreement created by two private properties. And I don't think that there's a place for that in all condition. So having the choir, the ruse of conduct makes sense, but that's the three strike rule.
# predicted label: 2
# getting prediction for:  you  Uh huh.  and
# predicted label: 2
# getting prediction for:  Yeah. And housing department, housing department enforcement, that's again, that's a regulatory compliance. I mean, that's just like building in safety. I don't think that we need to add additional language for something that City already does.
# predicted label: 2
# getting prediction for:  understand.  Yes, I just wanted to commission on Chunk Kim.  get a better understanding, especially when you say go through and check for this type of language that we fully understand the thought process of what kind of language it is that you're asking us to look for. Before we go into searching for all applicable findings, Commissioner Delgado, did you have any input and sites, questions?
# predicted label: 2
# getting prediction for:  Commissioner Doug out of no, I don't.
# predicted label: 2
# getting prediction for:  Commissioner Tronkin, so if we're all in agreement, I think the next step would be taking a couple moments to look through the findings and see how they apply to these three bullet points.
# predicted label: 2
# getting prediction for:  And that's the Alaska City Attorney's Office and it appreciates me that the third bullet point I think it's already at least according to staff's presentation already covered by the proposed modification of condition number 15. So I think that the room may be duplicative of condition number 15. But I'll let staff chime in if that is correct. Correct. Correct. Yes.
# predicted label: 2
# getting prediction for:  Thank you.
# predicted label: 2
# getting prediction for:  Thank you.
# predicted label: 2
# getting prediction for:  Thank you.
# predicted label: 2
# getting prediction for:  Thank you.
# predicted label: 2
# getting prediction for:  you
# predicted label: 2
# getting prediction for:  I'm sorry. The third bullet points is already covered. Yeah, it's covered by the condition number 15 So I think that we can strike that
# predicted label: 2
# getting prediction for:  that's the...  Yeah.
# predicted label: 2
# getting prediction for:  I can revise the second bullet point so that it will be  more appropriate.  just contain the Rs, that the property owner provide rules of conduct and then they are showing the quiet Rs starting at 11 PM. And for a vision of alcohol, drinking smoke or any.  of any kind outside or private residence, then that's it.
# predicted label: 2
# getting prediction for:  Commissioner Tonkin, while we're on that second bullet point, I'm being nitpicky, but can we make sure it's as quiet?
# predicted label: 2
# getting prediction for:  Yeah.  Yes, yes, yes, yes, that's quiet.
# predicted label: 2
# getting prediction for:  Excuse me, you are...
# predicted label: 2
# getting prediction for:  turn.  Commissioner and Tom Kim sorry we had our public testimony for the last hearing and so for this continuance we actually don't need to open up public testimony unless there is a motion by one of the commissioners to do so.  Thanks.  Commissioner Tonkant, there is no public testimony at this time and we're deliberating.
# predicted label: 2
# getting prediction for:  Commissioner Medes, just to understand what we're doing right now, we're looking through the findings and seeing how we can.  um, fit them to the men there.  Thank you.
# predicted label: 2
# getting prediction for:  Commissioner Chunkham, so for these two bullet points, I've removed the third one since it's a duplicate.  In order for us to actually make these part of the conditions of the CUP, we would have to find that if it's within the findings.  And so  If we are in agreement that we want these two bullet points submitted to us by the applicant to be part of the conditions, then we would have to.  He wanted to say find the finding.
# predicted label: 2
# getting prediction for:  This is Jane Choi with the Planning Department. Can I make a suggestion for finding? Sure. So I think in finding number one regarding the project will enhance.
# predicted label: 2
# getting prediction for:  Sure.
# predicted label: 2
# getting prediction for:  the built environment in the surrounding neighborhood or will perform a function or provide a service that is essential or beneficial to the community, city or region. So I think it's already established in the finding that  the project will provide a service.  that is essential or beneficial to the community, city, or region. But if you look on page 14,  actually at the bottom of page 13.  and continuing on to page 14, it talks about  allowing short-term rentals while maintaining the apartment use would make an efficient and flexible use and it continues on.  to talk about how the project would preserve long-term housing while addressing short-term.  residential occupancy issues. I would suggest adding a paragraph after that that talks about how at the hearing in the Area Planning Commission issues were raised regarding  the compatibility of  ability having both long-term leases and short-term leases.  and to address that, the commission is adding these two conditions to  allow for better noticing of  for our...  tenons both long term and short term.  to address the issues that were raised during the public testimony.
# predicted label: 2
# getting prediction for:  Mr. Tunkim, so can we just see you?  you  what you just said.  I'm going to refer back to your statement.  I have it then.  Okay.  there.
# predicted label: 2
# getting prediction for:  This is Ernesto Velasquez City Terms Office. Even when you make your motion, you can.  refer back to  senior city planner Jane Choi's comments and adopt those as the and adopt those or adopt those but just refer back to them when you're making your motion and incorporating these additional conditions into the approval.
# predicted label: 2
# getting prediction for:  Commissioner Tonkham, so would any of the commissioners like to make a motion?
# predicted label: 2
# getting prediction for:  I'd love to, Commissioner Dogaro, it's a little complicated. If you want to start me off, be glad to take it home. But I want to make sure that I have the overall framework of what it is that we've agreed to, and then how we can...  on the record kick it back to planning.
# predicted label: 2
# getting prediction for:  you  Commissioner Chong Kim. So we would be making a motion to grant the appeal and part.  and then...  It's in part because we will be adding new conditions and revising conditions 11, 12, 13 and 15. So adding the two conditions that were...  submitted to us by the applicant with the findings that senior sitting plenner, Jane Joy, made.  Does that help?  No.  No. Okay.  Commissioner Tunkim, I'll make the most. All right. Thank you.
# predicted label: 2
# getting prediction for:  Thank you.  you
# predicted label: 2
# getting prediction for:  Commissioner Chung-Kim, I make a motion to grant the appeal and part.  Determined based on the whole of the administrative record that the project is exempt from CEQA pursuant to Article 3, Section 1, Class 1, Category 22 of the CEQA guidelines and there is no substantial evidence demonstrating that an exception to a categorical exception pursuant to CEQA guidelines, Section 15300.2 applies. Grantee appeal in part and sustain in part the zoning administrators' determination to approve a conditional use permit to allow a transient occupancy residential structure addition to an existing residential dwelling use within 500 feet. Adopt the conditions of approval as modified by the commission.  and adopt the findings with the modifications suggested by the senior city planner, Jane Choi.
# predicted label: 2
# getting prediction for:  until we have seconds.
# predicted label: 2
# getting prediction for:  Commissioner Dugout, I second the motion.
# predicted label: 2
# getting prediction for:  At Orange Dung CEA, we have our first and second motion on the floor. Commissioner Chan Kim, how do you vote?
# predicted label: 2
# getting prediction for:  Yes.
# predicted label: 2
# getting prediction for:  Commission Delgado, how do you vote? Yes. Commissioner Mendez, how do you vote? Yes. Motion passed.
# predicted label: 2
# getting prediction for:  Thank you.  Yes.
# predicted label: 2
# getting prediction for:  you
# predicted label: 2
# getting prediction for:  you
# predicted label: 2
# getting prediction for:  Thank you.
# predicted label: 2
# getting prediction for:  Commissioner Chun Kim, so we're going to wait for the room to clear out before I move on to item number seven.
# predicted label: 2
# getting prediction for:  Thank you.
# predicted label: 2
# [2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  0,
#  2,
#  2,
#  2,
#  0,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  1,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  0,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  1,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  1,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  1,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2]

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, classification_report
import pandas as pd

accuracy = accuracy_score(truelabels_ls, predlabels_ls)
precision = precision_score(truelabels_ls, predlabels_ls, average='weighted')
recall = recall_score(truelabels_ls, predlabels_ls, average='weighted')

print(f"Accuracy: {accuracy:.2f}")
print(f"Precision: {precision:.2f}") 
print(f"Recall: {recall:.2f}")

report = classification_report(truelabels_ls, predlabels_ls, output_dict=True)
report_df = pd.DataFrame(report).transpose()
report_df = report_df.round(2)  # Round to 2 decimal places for better readability

report_df
# Out:
# Accuracy: 0.96
# Precision: 0.95
# Recall: 0.96
#               precision  recall  f1-score  support
# 0                  0.67    0.40      0.50     5.00
# 1                  0.50    0.22      0.31     9.00
# 2                  0.97    0.99      0.98   296.00
# accuracy           0.96    0.96      0.96     0.96
# macro avg          0.71    0.54      0.60   310.00
# weighted avg       0.95    0.96      0.95   310.00

# %%
# Find indices where true label is 0 but predicted as 2
zero_as_two = [(i, text_ls[i]) for i in range(len(truelabels_ls)) 
               if truelabels_ls[i] == 0 and predlabels_ls[i] == 2]

# Find indices where true label is 1 but predicted as 2  
one_as_two = [(i, text_ls[i]) for i in range(len(truelabels_ls))
              if truelabels_ls[i] == 1 and predlabels_ls[i] == 2]

print("Cases where true label was 0 but predicted as 2:")
for idx, text in zero_as_two:
    print(f"Index {idx}: {text}")
    
print("\nCases where true label was 1 but predicted as 2:")
for idx, text in one_as_two:
    print(f"Index {idx}: {text}")
# Out:
# Cases where true label was 0 but predicted as 2:
# Index 256:  or since they're next over last year's City Attorney's Office.  You can look at these three conditions and see if there's something in the findings that allow you to create, you know, what we call that nexus, you know, where we've discussed before in this commission. You know, what's the connection between these particular conditions and some effect of the project that, you know, according to the findings, you think needs to be addressed. So just as by way of guidance, if you look at finding number two, the projects location size high operations and other significant features, we'll be compatible with it. We'll not adversely affect refer to the degree adjacent properties surrounding neighborhood or the public health welfare and safety.  I think if you look at these three conditions that are proposed to be added to the project, and you look at the findings as currently drafted.  You may be able to articulate where these conditions fit in. For example, in paragraph two of the findings that's currently drafted, there's a discussion about existing tenants and about their current at least, agreements, really, and arrangements.  This first condition appears to me to...  be addressing issues related to what's being discussed in that second paragraph of finding number two.  Once again, now looking at the second proposed condition, the notice that the tends to be given that it's a mixed tenancy building and provided a rule of conduct, once again that might fall in under this second finding of making sure that this project is compatible with and will not further degrade adjacent properties, starting in neighborhood and so on.  the third  condition the  Member of Management staff being available, 24 hours a day at handle complaints. Once again, I fall into this same  to the law, GPI, and making this second finding the affirmative. So if the commission just wants to take a little bit of time to.  sort of digest what I've just said and see what you guys think in terms of these conditions, whether or not you think that there is, that next is that connection between these conditions.  some effect of the project that you think can be  addressed to these conditions.  I would just know on the subject of these conditions that the second condition regarding the rules of conduct, the portion a bit about the starts with that if breach would result in their immediate loss of right to occupy the premises.  Once again, I would just have the commission consider as far as enforcement goes. That seems like that might be something that's really between the less or and the less see and whether or not this commission wants to impose a condition. That seems more to go to the relationship between the less or less see just one thing to consider. Whether or not you think that language is appropriate and whether or not the city can effectively enforce that particular term of the condition.  Similar to that the three strike rule for complaints against such tenants and then being then asked to leave the premises once again I would just have the commission consider whether or not that's something that can be effectively and efficiently  you know, taking care of by the CEO whether or not that strikes the commission or something that really is between the lesser and the less e.
# Index 258:  Cesar Nusselvallasca City Attorney's Office, I have to think a little bit more about what language could be drafted to address that concern, but the concern that I just wanted to highlight to the commission was that  that issue of enforceability and  adopting and contracting conditions that can be  Uh...  that can be enforced with relative efficiency and effectiveness and those particular provisions just struck me as being a bit  difficult to
# Index 260:  to police and not on the LAPD sense of the word, but police in the sense of just how do we how does it ensure that such a condition is complied with. The having a rules of conduct is something that  Bye.  that we can, I think, we can reasonably enforce, it could be some requirement that the applicant present those rules of conduct to the department of city planning or to the relevant city department. It's just the result of what a breach of those rules of conduct mean.  may put the city in a position where it's  interjecting itself into issues or disputes between a less or an LSE and that is what struck me as being potentially difficult to enforce. But if someone more creative than me, if you or maybe staffed in, come up with language that might address the concerns that I've highlighted but still.  Take care of, I think what you...  I hope such a condition might accomplish. Perhaps we can come up with something, but I unfortunately don't have anything off the top of my head right now that I could present to you, but I'm sure if you...  you know if you can try to work with staff and see if they can think of anything that might be  that might address your concern while still being something that can be effectively enforced.
#
# Cases where true label was 1 but predicted as 2:
# Index 9:  So staff recommends denying the appeal and the project description.  It's for 39 residential units in the Hollywood community plan area. Point City of Place, this is just south of Sunset Boulevard and east of La Brea. It's a vacant site and it's 39 total units, 36 market rate and three affordable units. They were eligible for two incentives, a 20% decrease in the required front yard, allowing a depth of 12 feet and a 20% increase in the allowable FAR from 3 to 1 to 3.6 to 1, and it includes 78 parking spaces and complies with all other municipal code sections.  So state density bonus law states that when an applicant seeks a density bonus, the city is required to grant it unless the appellant can prove that either the incentives are not necessary for inclusion of the affordable units or that there's a detrimental impact on physical safety and the environment.  owner of the building directly.  to the south of the site and the appeal points had to do with environmental uses and conditions that were mitigated in the mitigated negative declaration. So the appeal points had to do with noise and dust during construction and then a couple of process issues.  This is the site. It just shows that it's a vacant site and it's surrounded by  other multifamily residential uses.  This shows that the residential area, it's R3 zoning, and then it's commercial, just a long-sense at Boulevard to the north of the site.  These are some pictures of the site. This is the actual vacant site with the building to the west of it.  This is the adjacent property on the north side by sunset boulevard. And this is the south, the property of the south, which is the appellance property.  This is across the street from the subject property just a typical multi-family building in the area.  And then we have some drawings that we included earlier today in your packet. And I'm good. I was going to have Nicole Sanchez, the staff planner come up and just walk you through. The findings are made based on design guidelines in the Hollywood community plan. And that's what the director's determination did was was look for facade articulation. But this just shows you I'll just have her walk you through the plans.
# Index 10:  after a new commissioners, Nicole Sanchez with the Pioneer Department. So the slide that you see here is the front elevation of the building facing east onto Punxeria Place.  As previously mentioned, this project is a density bonus project, therefore it complies with section 12.22, 825 of the LEMC.  which requires any density bonus project with on menu incentives to comply with certain design features.  This project also incorporates some of the Hollywood Community Plan Design Guidelines, as well as the Planning Department's City of White Residential Design Guidelines.  Some of those guidelines include articulation on the facade that are but a street with a change in material, textures or a break and plane.
# Index 14:  Okay.  So here is a summary of the appeal points that we received.  They're primarily related to the short-term construction impacts.  which have all been mitigated either through the M&D or conditioned in the director's determination.  So once again, we recommend denial of the appeal and sustaining the director's donation, approving, identity bonus compliance review. Great.
# Index 47:  So the appeal points, we responded since the appeal points had to do with impacts related to construction, such as noise and dust. And there were some points there that had to do with the process that we were just talking about. We, since an emitting a neck deck was prepared for it, the mitigation measures addressed all of the appeal points. And that was how we responded and recommended, it made our recommendation to deny the appeal.
# Index 62:  you  Yeah, the conditions. And they were repeated in the appeal letter as well.  So air pollution, demolition, grading, and construction activities were addressed, you know, such as  transported off site and wetting the dust, the standard mitigation measures for construction dirt.  There was also...  The ones having to do with noise and there was a minimum five foot and two foot landscape buffer to be put in against all walls.
# Index 116:  Hello, everyone. My name is Lucerito Martinez. I'm the project planner assigned to the case. The project consists of the demolition of an existing single family home and the subsequent construction of a three-story eight-unit apartment building with a semi-subterranean garage. It will provide a total of 15 parking spaces. The requested entitlements include a zone change from R1-1 to R3-1 to construct the 8-unit apartment building and also include say 15-foot building line removal created by ordinance 1-29661. The recommendation is to approve the categorical exemption class 32, the zone change from R1-1 to TQR3-1.  and the building line removal. And I'm here to answer any questions.
# Index 230:  Mr. Chang made an adequate description of what we thought about. We started thinking through a business plan and I think Commissioner Delgado kind of hit the nail on the head in some ways of saying, well, you know, what's fair? How do you divide things up? What floors do you put them on in the like?  And the way we started thinking about it from a business model perspective was for those people who have been there and were not subjected to a transient occupancy near them, it is unfair or potentially unfair to expose them to it without having a consolidated floor that is dedicated to them.  tenants left that we would move to two consolidated floors.  thereafter and those floors would remain such until such time as those tenants have either left or tenancy or not.  Then people who come in terms of the marketplace, we would provide, you'll see that in our business plan, there's a series of notices that are required. And the notices were meant to inform both individuals who want to rent on a long-term basis that this is an effect of a mixed apartment building and that there may be people who are a temporary occupant near them. And if so, these are their rights. And these are the ways that they can have complaints and these is how we will take care of them. And that way, they can make the decision on whether to rent the apartment or not. And if they're renting it, they're renting it with knowledge that they could be living next to someone who is a temporary occupant. On the flip side of that, we wanted to also notify the temporary occupants that they are living in a building that could have permanent residents and as such there is a code of conduct relative to that and given that there are temporary which would mean that they're less than 30 days there's a we've imposed a three strike rule if there's three complaints against the temporary resident they're out with without question you know and it would be three strikes within that 30 day period. That way ensuring that we are both serving the community that we are not going to be able to do that. We are not going to be able to do that without question, you know, and it would be three strikes within that 30-day period. That way ensuring that we are both serving the community that we want and providing the most flexibility for the building because the reality is as Mr. Chang identified, this is a very special part of Hollywood and we believe it serves a population of the studios in the entertainment industry and trying to be fair to the residents that exist there, giving them a longer term, allowing them to be on a separate floor during their whole tenancy and thereafter making sure that everyone is aware of the rules of the game. And that seemed like the wisest business plan so you didn't get into the question of how do you disperse what do you do, what's fair, what's not fair.
